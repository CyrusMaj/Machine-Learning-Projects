# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf

# %%
df = pd.read_csv("bank.csv")

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
duplicates = df.duplicated()
sum(duplicates)
# Out:
# 0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.hist(figsize=(20,10), bins=50);

# %%
#CustomerID looks unique, Row Number seems useless.

# %%
#Dropping columns
df.drop('RowNumber',axis=1,inplace=True)
df.drop('CustomerId',axis=1,inplace=True)
df.drop('Surname',axis=1,inplace=True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# Outlier detection, Univariate Boxplots
sns.set({'figure.figsize': (13,3)})
def box_plot(frame):
    for i in ['Age', 'Balance', 'CreditScore', 'EstimatedSalary', 'Exited', 'HasCrCard', 'IsActiveMember', 'NumOfProducts', 'Tenure']:
        sns.boxplot(df[i])
        plt.show()
            
box_plot(df)

# %%
#I decided that there are not enough outliers in the set to make removal worthwhile.

# %% [markdown]
# # Bivariate Analysis

# %%
#Heatmap
sns.set({'figure.figsize': (15,15)})
sns.heatmap(df.corr(), annot=True);

# %%
#No real coorelation between features

# %%
#pairplot
sns.pairplot(df, diag_kind='kde');
# Out:
# /Users/cyrusmajidy/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
df.skew()
# Out:
# CreditScore       -0.071607
# Age                1.011320
# Tenure             0.010991
# Balance           -0.141109
# NumOfProducts      0.745568
# HasCrCard         -0.901812
# IsActiveMember    -0.060437
# EstimatedSalary    0.002085
# Exited             1.471611
# dtype: float64

# %%
#Encode variables/get dummies
df = pd.get_dummies(df, columns=['Geography','Gender'])
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0               1        101348.88       1                 1
# 1               1        112542.58       0                 0
# 2               0        113931.57       1                 1
# 3               0         93826.63       0                 1
# 4               1         79084.10       0                 0
#
#    Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0                  0                0              1            0
# 1                  0                1              1            0
# ...

# %%
# Scaling the data
from sklearn.preprocessing import StandardScaler
std_scale = StandardScaler()
std_scale
# Out:
# StandardScaler()

# %%
df['Age'] = std_scale.fit_transform(df[['Age']])
df['Balance'] = std_scale.fit_transform(df[['Balance']])
df['CreditScore'] = std_scale.fit_transform(df[['CreditScore']])
df['EstimatedSalary'] = std_scale.fit_transform(df[['EstimatedSalary']])
df['NumOfProducts'] = std_scale.fit_transform(df[['NumOfProducts']])
df['Tenure'] = std_scale.fit_transform(df[['Tenure']])

# %%
df.head()
# Out:
#    CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0    -0.326221  0.293517 -1.041760 -1.225848      -0.911583          1
# 1    -0.440036  0.198164 -1.387538  0.117350      -0.911583          0
# 2    -1.536794  0.293517  1.032908  1.333053       2.527057          1
# 3     0.501521  0.007457 -1.387538 -1.225848       0.807737          0
# 4     2.063884  0.388871 -1.041760  0.785728      -0.911583          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0               1         0.021886       1                 1
# 1               1         0.216534       0                 0
# 2               0         0.240687       1                 1
# 3               0        -0.108918       0                 1
# 4               1        -0.365276       0                 0
#
#    Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0                  0                0              1            0
# ...

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

#It looks like "Exited" is the variable we are solving for in order to predict if the customer will exit.
x = df.drop('Exited', axis=1)
y = df['Exited']

#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
x_train, x_val_and_test, y_train, y_val_and_test = train_test_split(x, y, test_size=0.3)
x_val, x_test, y_val, y_test = train_test_split(x_val_and_test, y_val_and_test, test_size=0.5)

# %%
print(x_train.shape, x_val.shape, x_test.shape, y_train.shape, y_val.shape, y_test.shape)
# Out:
# (7000, 13) (1500, 13) (1500, 13) (7000,) (1500,) (1500,)

# %%
#Build model

# %%
from keras.models import Sequential
from keras.layers import Dense

#Decided to have 32 neurons, 10 input features, 1 neuron for output class.

model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(13,)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# Using TensorFlow backend.

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'],)

# %%
#Best results
hist = model.fit(x_train, y_train,
          batch_size=32, epochs=100, 
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Train on 7000 samples, validate on 1500 samples
# Epoch 1/100
# 7000/7000 [==============================] - 1s 107us/step - loss: 0.5226 - accuracy: 0.7930 - val_loss: 0.4875 - val_accuracy: 0.7987
# Epoch 2/100
# 7000/7000 [==============================] - 0s 50us/step - loss: 0.4743 - accuracy: 0.7951 - val_loss: 0.4566 - val_accuracy: 0.7987
# Epoch 3/100
# 7000/7000 [==============================] - 0s 49us/step - loss: 0.4494 - accuracy: 0.7951 - val_loss: 0.4365 - val_accuracy: 0.7980
# Epoch 4/100
# 7000/7000 [==============================] - 0s 49us/step - loss: 0.4330 - accuracy: 0.7970 - val_loss: 0.4230 - val_accuracy: 0.8060
# Epoch 5/100
# 7000/7000 [==============================] - 0s 49us/step - loss: 0.4219 - accuracy: 0.8061 - val_loss: 0.4136 - val_accuracy: 0.8140
# Epoch 6/100
# 7000/7000 [==============================] - 0s 48us/step - loss: 0.4142 - accuracy: 0.8180 - val_loss: 0.4065 - val_accuracy: 0.8253
# Epoch 7/100
# ...

# %%
#To see the accuracy of our test set
model.evaluate(x_test, y_test)[1]
# Out:
# 1500/1500 [==============================] - 0s 21us/step
# 0.846666693687439

# %%
#Visualize the training and validation loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
#Visualize the training and validation accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
#Predict
#I believe threshold is 0.5 by default. I could also use predict_classes()
prediction = model.predict(x_test)

for i in prediction:
    print(i)
# Out:
# [0.5768887]
# [0.0082334]
# [0.4138107]
# [0.05892015]
# [0.12314367]
# [0.04594892]
# [0.33236557]
# [0.07334024]
# [0.07789806]
# [0.4816419]
# [0.7867186]
# [0.9175111]
# [0.5056772]
# [0.24216697]
# [0.28721613]
# [0.02107179]
# [0.7896364]
# [0.45540923]
# [0.00953758]
# [0.13188705]
# [0.06296515]
# [0.00652385]
# [0.42111558]
# [0.05400583]
# [0.05956912]
# [0.22101998]
# [0.17045507]
# [0.02638012]
# [0.01770243]
# [0.00659961]
# [0.5704863]
# [0.20080131]
# [0.133006]
# [0.16366288]
# [0.04830343]
# [0.04571632]
# [0.11517629]
# [0.07025331]
# [0.01331913]
# [0.11162275]
# [0.15478909]
# [0.02752304]
# [0.62798953]
# [0.22250772]
# [0.68333846]
# [0.29963422]
# [0.09854472]
# [0.00892946]
# [0.5136419]
# [0.12265289]
# [0.05836067]
# [0.01444638]
# [0.1016466]
# [0.8830205]
# [0.10175198]
# [0.14225787]
# [0.1699974]
# [0.20299754]
# [0.26302844]
# [0.3907761]
# [0.20665267]
# [0.43018603]
# [0.03862897]
# [0.46728206]
# [0.0240576]
# [0.268883]
# [0.19107437]
# ...

# %%
print(prediction)
# Out:
# [[0.5768887 ]
#  [0.0082334 ]
#  [0.4138107 ]
#  ...
#  [0.01978844]
#  [0.00998721]
#  [0.1517852 ]]

# %%
#Confusion matrix
from sklearn import metrics
from sklearn.metrics import confusion_matrix

print("Confusion Matrix:  ", "\n"), 

cm_array = metrics.confusion_matrix(y_test, y_val, labels=[1,0])
cm = np.flip(cm_array) 
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='g', xticklabels=[1,0], yticklabels=[1,0]);
# Out:
# Confusion Matrix:

# %%
#Attempting to Improve the model by tweaking parameters
from keras.layers import Dropout
from keras import regularizers
from keras import layers
from keras import models
from keras import utils
from keras.layers import Flatten
from keras.layers import Activation
from keras.regularizers import l2
from keras.optimizers import SGD
from keras.optimizers import RMSprop
from keras.callbacks import LearningRateScheduler
from keras.callbacks import History
from keras import losses
from sklearn.utils import shuffle

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
model = Sequential()
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(13,)))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)))

# %%
#Setting the SGD values
epochs=100
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8

sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'],)

# %%
hist = model.fit(x_train, y_train,
          batch_size=60, epochs=100, 
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Train on 7000 samples, validate on 1500 samples
# Epoch 1/100
# 7000/7000 [==============================] - 1s 147us/step - loss: 1.1419 - accuracy: 0.6687 - val_loss: 1.0255 - val_accuracy: 0.7947
# Epoch 2/100
# 7000/7000 [==============================] - 0s 42us/step - loss: 1.0250 - accuracy: 0.7894 - val_loss: 0.9745 - val_accuracy: 0.7947
# Epoch 3/100
# 7000/7000 [==============================] - 0s 43us/step - loss: 0.9772 - accuracy: 0.7939 - val_loss: 0.9390 - val_accuracy: 0.7947
# Epoch 4/100
# 7000/7000 [==============================] - 0s 42us/step - loss: 0.9469 - accuracy: 0.7953 - val_loss: 0.9094 - val_accuracy: 0.7947
# Epoch 5/100
# 7000/7000 [==============================] - 0s 42us/step - loss: 0.9128 - accuracy: 0.7953 - val_loss: 0.8833 - val_accuracy: 0.7947
# Epoch 6/100
# 7000/7000 [==============================] - 0s 42us/step - loss: 0.8858 - accuracy: 0.7961 - val_loss: 0.8600 - val_accuracy: 0.7947
# Epoch 7/100
# ...

# %%
#To see the accuracy of our test set
model.evaluate(x_test, y_test)[1]
# Out:
# 1500/1500 [==============================] - 0s 24us/step
# 0.8299999833106995

# %%
#Visualize the training and validation loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
#Visualize the training and validation accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
#Predict
prediction = model.predict(x_test)

for i in prediction:
    print(i)
# Out:
# [0.376806]
# [0.11938933]
# [0.08569276]
# [0.53247535]
# [0.37471235]
# [0.11918119]
# [0.20336574]
# [0.06669286]
# [0.5316935]
# [0.08192289]
# [0.09453335]
# [0.11758086]
# [0.20053753]
# [0.21982688]
# [0.1279822]
# [0.3895262]
# [0.19732332]
# [0.38689595]
# [0.06742087]
# [0.24046662]
# [0.05886471]
# [0.23074055]
# [0.3108655]
# [0.1589581]
# [0.17067412]
# [0.04455432]
# [0.13320342]
# [0.33297342]
# [0.56966037]
# [0.12722519]
# [0.09053645]
# [0.12240764]
# [0.1203396]
# [0.22114557]
# [0.22666323]
# [0.35194242]
# [0.14720109]
# [0.05851161]
# [0.16445673]
# [0.10976806]
# [0.16922808]
# [0.19920418]
# [0.19794416]
# [0.3347751]
# [0.3652814]
# [0.19134521]
# [0.31663063]
# [0.17443231]
# [0.4545282]
# [0.46420705]
# [0.5173129]
# [0.06354341]
# [0.39195198]
# [0.09795091]
# [0.28081745]
# [0.08451158]
# [0.21851659]
# [0.5597746]
# [0.11420995]
# [0.13080606]
# [0.34320515]
# [0.2899052]
# [0.07983169]
# [0.06427008]
# [0.44332972]
# [0.14682516]
# [0.09347564]
# ...

# %%
print(prediction)
# Out:
# [[0.376806  ]
#  [0.11938933]
#  [0.08569276]
#  ...
#  [0.09449849]
#  [0.38790786]
#  [0.45105678]]

# %%
#Confusion matrix
from sklearn import metrics
from sklearn.metrics import confusion_matrix

print("Confusion Matrix:  ", "\n"), 

cm_array = metrics.confusion_matrix(y_test, y_val, labels=[1,0])
cm = np.flip(cm_array) 
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='g', xticklabels=[1,0], yticklabels=[1,0]);
# Out:
# Confusion Matrix:

# %%
#As we can see, the 1st attempt was my best.
